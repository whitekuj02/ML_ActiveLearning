# %%
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.4)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163752 sha256=aaaa13e1abf7546feccb521dad4ee4f392bfb9bf66b96d5d86355cd5850cdff4
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3

# %%
from surprise import Reader, Dataset, SVD, KNNWithMeans
from surprise.model_selection import train_test_split
from surprise import accuracy

# %%
df = pd.read_csv('/content/sampled_result_encoded_500000.csv')
df.head()
# Out:
#    UserID     StreamID StreamerName  TimeStart  TimeStop  WatchTime  \
# 0   49907  33938860608     alcasthq       1105      1106         10
# 1   59803  33915106176     stray228        847       848         10
# 2   13819  33904450096  senseifaruk        741       743         20
# 3   32503  34402554000       xgladd       6055      6058         30
# 4   38317  34125070304       dafran       3102      3103         10
#
#    encoded_StreamerName StartTime StopTime
# 0                  2331     16:10    16:20
# 1                 73836     21:10    21:20
# 2                 68363     03:30    03:50
# 3                 85835     01:10    01:40
# 4                 15825     13:00    13:10

# %%
# 이상치 제거 함수
# Function to remove outliers from specified columns in a DataFrame
def get_outlier(df, column, weight=1.5):
    for c in column:
        quantile_25 = np.percentile(df[c].values, 25)
        quantile_75 = np.percentile(df[c].values, 75)

        iqr = quantile_75 - quantile_25
        iqr_weight = iqr * weight

        lowest = quantile_25 - iqr_weight
        highest = quantile_75 + iqr_weight

        outlier_idx = df[c][(df[c] < lowest) | (df[c] > highest)].index
        df = df.drop(outlier_idx)
    return df

# 데이터 전처리 함수
# Data preprocessing function to clean and filter the dataset
# Removing users with a low number of interactions
# Removing streams with low viewership
# Removing outliers based on watch time
def preprocess(df, weight=1.5, percent=0.1):
    # Removing users with a low number of interactions
    user_counts = df['UserID'].value_counts().reset_index()
    user_counts.columns = ['UserID', 'count']
    top_percent_value = user_counts['count'].quantile(1 - percent)
    filtered_users = user_counts[user_counts['count'] < top_percent_value]
    df = df[~df['UserID'].isin(filtered_users['UserID'])]

    # Removing streams with low viewership
    stream_counts = df['StreamID'].value_counts().reset_index()
    stream_counts.columns = ['StreamID', 'count']
    top_percent_value = stream_counts['count'].quantile(1 - percent)
    filtered_streams = stream_counts[stream_counts['count'] < top_percent_value]
    df = df[~df['StreamID'].isin(filtered_streams['StreamID'])]

    # Removing outliers based on watch time
    df['WatchTime'] = (df['TimeStop'] - df['TimeStart']) * 10
    df = get_outlier(df, ['WatchTime'], weight)
    df = df.reset_index(drop=True)

    return df

# 데이터 샘플링 및 전처리
df_cleaned = preprocess(df, 1.5, 0.1)
# Applying preprocessing to the entire dataset and a sampled subset
sampled_df = df.sample(n=150000, random_state=42)
sampled_df_cleaned = preprocess(sampled_df, 1.5, 0.1)

df_cleaned, sampled_df_cleaned
# Out:
# (       UserID     StreamID  StreamerName  TimeStart  TimeStop  WatchTime  \
#  0       38317  34125070304        dafran       3102      3103         10
#  1       36286  34392526368       solaaaa       5872      5873         10
#  2       28019  33915571520      rainbow6        855       856         10
#  3        6603  34320625760  timthetatman       5153      5154         10
#  4       97815  33894454656   moonmoon_ow        623       624         10
#  ...       ...          ...           ...        ...       ...        ...
#  42378   73123  34410333264    nanajam777       6102      6104         20
#  42379   15112  33995804480     innocents       1699      1700         10
#  42380   37801  34040314016          chap       2178      2179         10
#  42381   74334  34152472176    methodjosh       3434      3435         10
#  42382   17790  33844677744      dasmehdi        155       157         20
#
#         encoded_StreamerName StartTime StopTime
#  0                     15825     13:00    13:10
#  1                     71873     18:40    18:50
#  2                     63068     22:30    22:40
#  3                     78888     18:50    19:00
#  4                     51456     07:50    08:00
#  ...                     ...       ...      ...
#  42378                 53553     09:00    09:20
#  42379                 33806     19:10    19:20
#  42380                 12276     03:00    03:10
#  42381                 49419     20:20    20:30
#  42382                 16694     01:50    02:10
#
#  [42383 rows x 9 columns],
#         UserID     StreamID     StreamerName  TimeStart  TimeStop  WatchTime  \
#  0       78354  33868545328        elmiillor        412       413         10
#  1        2974  34308736544        asmongold       5006      5007         10
#  2       93089  33877459952  playhearthstone        506       508         20
#  3       50653  34106277712            iddqd       2902      2903         10
#  4       32981  34334225232     timthetatman       5301      5304         30
#  ...       ...          ...              ...        ...       ...        ...
#  20899   28480  34203524448          ricegum       3930      3931         10
#  20900   31638  34023290912          gingitv       2010      2011         10
#  20901   34760  34266426032           sharkz       4617      4619         20
#  20902   99801  34183532496           drlupo       3736      3737         10
#  20903   91829  33926802224         kabajiow        986       989         30
#
#         encoded_StreamerName StartTime StopTime
#  0                     21504     20:40    20:50
#  1                      5111     18:20    18:30
#  2                     60525     12:20    12:40
#  3                     32669     03:40    03:50
#  4                     78888     19:30    20:00
#  ...                     ...       ...      ...
#  20899                 64775     07:00    07:10
#  20900                 27890     23:00    23:10
#  20901                 69064     01:30    01:50
#  20902                 20001     22:40    22:50
#  20903                 38334     20:20    20:50
#
#  [20904 rows x 9 columns])

# %%
# Converting 'StartTime' and 'StopTime' to datetime objects and then formatting as strings to display only hours and minutes
sampled_df_cleaned['StartTime'] = pd.to_datetime(sampled_df_cleaned['StartTime'], format='%H:%M').dt.strftime('%H:%M')
sampled_df_cleaned['StopTime'] = pd.to_datetime(sampled_df_cleaned['StopTime'], format='%H:%M').dt.strftime('%H:%M')

# Extracting time of day features
sampled_df_cleaned['TimeOfDay'] = pd.to_datetime(sampled_df_cleaned['StartTime'], format='%H:%M').dt.hour.apply(
    lambda x: 'Morning' if 5 <= x < 12 else ('Afternoon' if 12 <= x < 17 else ('Evening' if 17 <= x < 21 else 'Night'))
)

# Display the first few rows to verify the changes
sampled_df_cleaned.head()
# Out:
#    UserID     StreamID     StreamerName  TimeStart  TimeStop  WatchTime  \
# 0   78354  33868545328        elmiillor        412       413         10
# 1    2974  34308736544        asmongold       5006      5007         10
# 2   93089  33877459952  playhearthstone        506       508         20
# 3   50653  34106277712            iddqd       2902      2903         10
# 4   32981  34334225232     timthetatman       5301      5304         30
#
#    encoded_StreamerName StartTime StopTime  TimeOfDay
# 0                 21504     20:40    20:50    Evening
# 1                  5111     18:20    18:30    Evening
# 2                 60525     12:20    12:40  Afternoon
# 3                 32669     03:40    03:50      Night
# 4                 78888     19:30    20:00    Evening

# %%
# 시간대별 시청 패턴 매트릭스 생성
# Creating a viewing pattern matrix by time zone
time_of_day_watching = sampled_df_cleaned.groupby(['UserID', 'TimeOfDay'])['WatchTime'].sum().unstack(fill_value=0)
time_of_day_watching = time_of_day_watching.div(time_of_day_watching.sum(axis=1), axis=0)

# %%
from scipy.sparse import csr_matrix

# User ID와 encoded_StreamerName에 대한 숫자 인덱스 할당
user_ids = sampled_df_cleaned['UserID'].astype('category').cat.codes
streamer_names = sampled_df_cleaned['StreamerName'].astype('category').cat.codes

# CSR 행렬 생성
watch_time = sampled_df_cleaned['WatchTime'].astype(float)
user_item_matrix = csr_matrix((watch_time, (user_ids, streamer_names)),
                              shape=(user_ids.max() + 1, streamer_names.max() + 1))

#스트리머 이름과 인덱스 매핑
streamer_index_to_name_mapping = dict(enumerate(sampled_df_cleaned['StreamerName'].astype('category').cat.categories))

# CSR 행렬 확인
print(user_item_matrix)
# Out:
#   (0, 1209)	10.0
#   (0, 1211)	10.0
#   (1, 245)	10.0
#   (1, 1598)	10.0
#   (2, 72)	10.0
#   (2, 646)	20.0
#   (2, 1634)	10.0
#   (3, 381)	10.0
#   (3, 1256)	20.0
#   (3, 1522)	10.0
#   (4, 111)	10.0
#   (4, 376)	10.0
#   (4, 1136)	20.0
#   (4, 1711)	10.0
#   (5, 566)	10.0
#   (6, 372)	30.0
#   (7, 108)	10.0
#   (7, 413)	20.0
#   (7, 933)	10.0
#   (7, 1366)	10.0
#   (8, 327)	20.0
#   (8, 463)	20.0
#   (8, 662)	10.0
#   (8, 1635)	10.0
#   (9, 1634)	20.0
#   :	:
#   (7152, 1804)	10.0
#   (7153, 600)	10.0
#   (7154, 312)	10.0
#   (7155, 1670)	30.0
#   (7156, 364)	20.0
#   (7156, 642)	10.0
#   (7156, 1151)	20.0
#   (7157, 1299)	10.0
#   (7157, 1474)	10.0
#   (7158, 1317)	20.0
#   (7158, 1735)	20.0
#   (7159, 413)	10.0
#   (7159, 1518)	10.0
#   (7159, 1580)	30.0
#   (7159, 1635)	10.0
#   (7160, 737)	20.0
#   (7160, 1048)	30.0
#   (7160, 1444)	20.0
#   (7160, 1634)	10.0
#   (7161, 27)	30.0
#   (7161, 608)	20.0
#   (7161, 1145)	10.0
#   (7161, 1521)	30.0
#   (7162, 986)	20.0
#   (7162, 1137)	10.0

# %%
from surprise import Reader, Dataset, SVD, KNNWithMeans
from surprise.model_selection import cross_validate, train_test_split
from surprise import accuracy
# Surprise에 사용하기 위한 데이터셋/ CSR 행렬에서 데이터프레임으로 변환
data_df = pd.DataFrame({
    'uid': user_ids,
    'iname': streamer_names,
    'rating': watch_time
})

# Surprise의 Reader 객체 생성/Rating scale은 최소 및 최대 시청 시간
reader = Reader(rating_scale=(data_df['rating'].min(), data_df['rating'].max()))

data = Dataset.load_from_df(data_df[['uid', 'iname', 'rating']], reader)

trainset, testset = train_test_split(data, test_size=0.25)

# %%
# SVD 모델 훈련(Gradient Descent, Regularization 최적화를 수행)
# 행렬 분해 기반 협업 필터링
# 사용자와 아이템 간의 상호작용(시청 시간)을 기반으로 행렬을 분해하고, 사용자가 아직 평가하지 않은 아이템에 대한 예측 평가를 생성.
svd = SVD()
svd.fit(trainset)

# KNNWithMeans 모델 훈련
# 이웃 기반의 협업 필터링
# 유사한 시청기록, 유사도를 바탕으로 사용자가 평가하지 않은 아이템에 대한 평가를 예측
knn = KNNWithMeans()
knn.fit(trainset)

# 훈련 모델 평가
svd_predictions = svd.test(testset)
knn_predictions = knn.test(testset)

# RMSE 모델 평가
svd_rmse = accuracy.rmse(svd_predictions)
knn_rmse = accuracy.rmse(knn_predictions)

print(f'SVD Model RMSE: {svd_rmse}')
print(f'KNNWithMeans Model RMSE: {knn_rmse}')
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 7.2200
# RMSE: 8.3684
# SVD Model RMSE: 7.2200031992314395
# KNNWithMeans Model RMSE: 8.368444813795128

# %%
# 모델의 예측을 조합하고 시간대 정보를 추가
def combine_predictions_with_time(svd_model, knn_model, time_pref_matrix, testset, current_time_of_day):
    combined_predictions = defaultdict(list)
    for svd_pred, knn_pred in zip(svd_model.test(testset), knn_model.test(testset)):
        uid = svd_pred.uid
        iid = svd_pred.iid
        avg_score = (svd_pred.est + knn_pred.est) / 2
        # 시간대 가중치를 적용
        time_weighted_score = avg_score * time_pref_matrix.loc[uid, current_time_of_day] if uid in time_pref_matrix.index else avg_score
        combined_predictions[uid].append((iid, time_weighted_score))
    return combined_predictions

# 현재 시간대 설정
current_time_of_day = 'Evening'

# 최종 결합된 예측 점수를 계산
final_predictions = combine_predictions_with_time(svd, knn, time_of_day_watching, testset, current_time_of_day)

# %%
# 최종 추천 목록을 생성하고, 스트리머 이름으로 출력하는 함수
# Function to generate top N recommendations for each user
def get_top_n_recommendations(predictions, n=3):
    top_n_recommendations = defaultdict(list)
    for uid, user_predictions in predictions.items():
        user_predictions.sort(key=lambda x: x[1], reverse=True)
        top_n_recommendations[uid] = user_predictions[:n]
    return top_n_recommendations

top_n_recommendations = get_top_n_recommendations(final_predictions, n=3)

# Printing the top recommendations for each user
for uid, user_recs in top_n_recommendations.items():
    print(f"User {uid}:")
    for iid, score in user_recs:
        streamer_name = streamer_index_to_name_mapping[iid]
        print(f"  Recommended Streamer: {streamer_name}, Score: {score:.2f}")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   Recommended Streamer: fortnite, Score: 19.94
#   Recommended Streamer: highdistortion, Score: 19.23
# User 6718:
#   Recommended Streamer: tfblade, Score: 14.39
# User 4768:
#   Recommended Streamer: luladopub, Score: 7.22
# User 1258:
#   Recommended Streamer: playhearthstone, Score: 17.45
#   Recommended Streamer: gamesdonequick, Score: 14.43
# User 5859:
#   Recommended Streamer: zerator, Score: 12.47
# User 1834:
#   Recommended Streamer: jahrein, Score: 11.85
# User 488:
#   Recommended Streamer: loeya, Score: 14.19
# User 918:
#   Recommended Streamer: c9sneaky, Score: 14.65
# User 294:
#   Recommended Streamer: dakotaz, Score: 14.60
#   Recommended Streamer: dakotaz, Score: 14.60
# User 5252:
#   Recommended Streamer: shroud, Score: 22.29
#   Recommended Streamer: dogdog, Score: 20.18
# User 6294:
#   Recommended Streamer: solaryfortnite, Score: 5.19
#   Recommended Streamer: fortnite, Score: 4.93
#   Recommended Streamer: gotaga, Score: 3.80
# User 1059:
#   Recommended Streamer: dreamhackcs, Score: 11.67
# User 4709:
#   Recommended Streamer: mandiocaa1, Score: 16.27
# User 6531:
#   Recommended Streamer: jtgtv, Score: 13.46
# User 4507:
#   Recommended Streamer: gosu, Score: 11.74
# User 2236:
#   Recommended Streamer: elwind, Score: 18.53
#   Recommended Streamer: stansfield, Score: 11.28
# User 61:
#   Recommended Streamer: hasanabi, Score: 20.72
# User 3391:
#   Recommended Streamer: trymacs, Score: 10.39
# User 151:
#   Recommended Streamer: kingrichard, Score: 12.05
# User 3325:
#   Recommended Streamer: epicenter_en2, Score: 12.89
#   Recommended Streamer: wagamamatv, Score: 11.66
# User 5627:
#   Recommended Streamer: kimuhtv, Score: 11.86
#   Recommended Streamer: thdlock, Score: 11.59
# User 4802:
#   Recommended Streamer: ashlynn, Score: 14.71
#   Recommended Streamer: drlupo, Score: 13.80
# User 4657:
#   Recommended Streamer: jovirone, Score: 0.00
#   Recommended Streamer: flanalistaa, Score: 0.00
#   Recommended Streamer: gratis150ml, Score: 0.00
# User 976:
#   Recommended Streamer: buddha, Score: 17.96
# User 4168:
#   Recommended Streamer: somagreen, Score: 14.44
# User 5287:
#   Recommended Streamer: moonmoon_ow, Score: 13.82
# User 3812:
#   Recommended Streamer: moonmoon_ow, Score: 10.04
# User 2942:
#   Recommended Streamer: playhearthstone, Score: 18.67
# User 4439:
#   Recommended Streamer: arthas, Score: 15.20
#   Recommended Streamer: qsnake, Score: 14.68
# User 5683:
#   Recommended Streamer: xargon0731, Score: 12.09
# User 1555:
#   Recommended Streamer: gotaga, Score: 18.82
# User 366:
#   Recommended Streamer: realvivien, Score: 14.44
# User 4964:
#   Recommended Streamer: ninja, Score: 29.33
#   Recommended Streamer: fortnite, Score: 15.29
# User 1489:
#   Recommended Streamer: gotaga, Score: 0.00
# User 2553:
#   Recommended Streamer: ninja, Score: 3.19
#   Recommended Streamer: stray228, Score: 2.27
# User 240:
#   Recommended Streamer: tekken, Score: 18.01
# User 108:
#   Recommended Streamer: parnstarzilean, Score: 22.82
# User 2105:
#   Recommended Streamer: tfue, Score: 19.49
# User 3374:
#   Recommended Streamer: stray228, Score: 14.35
#   Recommended Streamer: stray228, Score: 14.35
# User 3770:
#   Recommended Streamer: mckytv, Score: 20.48
#   Recommended Streamer: trymacs, Score: 16.22
# User 4373:
#   Recommended Streamer: c9sneaky, Score: 7.32
# User 6747:
#   Recommended Streamer: ninja, Score: 17.68
#   Recommended Streamer: ninja, Score: 17.68
#   Recommended Streamer: cdewx, Score: 13.38
# User 2:
#   Recommended Streamer: hashinshin, Score: 13.49
# User 1624:
#   Recommended Streamer: ninja, Score: 10.12
# User 2008:
#   Recommended Streamer: levo, Score: 12.51
# User 2511:
#   Recommended Streamer: twitchpresents, Score: 0.00
# User 2571:
#   Recommended Streamer: symfuhny, Score: 12.35
# User 5231:
#   Recommended Streamer: maciejay, Score: 18.01
#   Recommended Streamer: itshafu, Score: 17.74
#   Recommended Streamer: pokimane, Score: 13.99
# User 5588:
#   Recommended Streamer: dreadztv, Score: 14.74
# User 4600:
#   Recommended Streamer: amaz, Score: 14.12
# User 908:
#   Recommended Streamer: dafran, Score: 14.51
# User 6316:
#   Recommended Streamer: diegosaurs, Score: 15.55
# User 2102:
#   Recommended Streamer: ninja, Score: 12.40
# User 3897:
#   Recommended Streamer: yassuo, Score: 12.34
#   Recommended Streamer: shiphtur, Score: 12.24
# User 5487:
#   Recommended Streamer: reynad27, Score: 17.58
#   Recommended Streamer: cdewx, Score: 11.46
#   Recommended Streamer: nightblue3, Score: 11.33
# User 2228:
#   Recommended Streamer: yassuo, Score: 18.27
#   Recommended Streamer: pokimane, Score: 11.80
# User 4059:
#   Recommended Streamer: rekkles, Score: 14.11
# User 423:
#   Recommended Streamer: afro, Score: 16.87
# User 2648:
#   Recommended Streamer: lvpes, Score: 12.68
# User 5870:
#   Recommended Streamer: rajjpatel, Score: 11.38
# User 805:
#   Recommended Streamer: shroud, Score: 15.55
# User 2484:
#   Recommended Streamer: trymacs, Score: 12.37
# User 2605:
#   Recommended Streamer: prestige, Score: 12.52
# User 2890:
#   Recommended Streamer: amouranth, Score: 15.17
# User 2871:
#   Recommended Streamer: iamdiamond, Score: 13.51
# User 5527:
#   Recommended Streamer: pokimane, Score: 14.44
# User 1805:
#   Recommended Streamer: cigarettestv, Score: 12.67
# User 1612:
#   Recommended Streamer: yumyumyu77, Score: 11.73
# User 1166:
#   Recommended Streamer: dreamhackcs, Score: 12.66
#   Recommended Streamer: coscu, Score: 12.12
# User 6238:
#   Recommended Streamer: shroud, Score: 12.71
# User 4367:
#   Recommended Streamer: solorenektononly, Score: 12.09
# User 1682:
#   Recommended Streamer: kinggeorgetv, Score: 12.24
# User 4658:
#   Recommended Streamer: iamdiamond, Score: 13.51
# User 787:
#   Recommended Streamer: riotgames, Score: 11.47
#   Recommended Streamer: lilypichu, Score: 11.37
# User 5834:
#   Recommended Streamer: loeya, Score: 16.96
#   Recommended Streamer: shroud, Score: 15.06
# User 5006:
#   Recommended Streamer: alanzoka, Score: 11.30
# User 4425:
#   Recommended Streamer: nifex8, Score: 14.84
# User 6602:
#   Recommended Streamer: greekgodx, Score: 17.87
# User 1869:
#   Recommended Streamer: lirik, Score: 13.75
#   Recommended Streamer: lobosjr, Score: 11.28
# User 6770:
#   Recommended Streamer: ninja, Score: 4.30
# User 6016:
#   Recommended Streamer: sodapoppin, Score: 14.63
#   Recommended Streamer: spaceboy, Score: 12.05
# User 2473:
#   Recommended Streamer: buddha, Score: 18.17
#   Recommended Streamer: sodapoppin, Score: 10.83
# User 1538:
#   Recommended Streamer: hanryang1125, Score: 12.09
#   Recommended Streamer: rhdgurwns, Score: 12.07
#   Recommended Streamer: playhearthstone, Score: 11.99
# User 6158:
#   Recommended Streamer: alanzoka, Score: 11.39
# User 5503:
#   Recommended Streamer: alohadancetv, Score: 11.59
# User 555:
#   Recommended Streamer: mithrain, Score: 15.80
# User 1196:
#   Recommended Streamer: a_seagull, Score: 21.65
#   Recommended Streamer: kabajiow, Score: 17.51
# User 3817:
#   Recommended Streamer: chocotaco, Score: 15.09
# User 5241:
#   Recommended Streamer: hashinshin, Score: 17.08
#   Recommended Streamer: raizqt, Score: 17.02
# User 419:
#   Recommended Streamer: xargon0731, Score: 13.59
# User 5106:
#   Recommended Streamer: esl_csgo, Score: 10.01
# User 3233:
#   Recommended Streamer: ydcb, Score: 14.54
# User 4502:
#   Recommended Streamer: sodapoppin, Score: 11.45
# User 241:
#   Recommended Streamer: mickalow, Score: 12.95
# User 6677:
#   Recommended Streamer: chocotaco, Score: 15.09
#   Recommended Streamer: nickmercs, Score: 14.47
# User 2458:
#   Recommended Streamer: skipnho, Score: 13.83
# User 686:
#   Recommended Streamer: nanajam777, Score: 6.79
#   Recommended Streamer: cocopopp671, Score: 5.32
# User 850:
#   Recommended Streamer: rajjpatel, Score: 11.75
#   Recommended Streamer: erobb221, Score: 11.69
# User 6441:
#   Recommended Streamer: gronkh, Score: 12.12
# User 6887:
#   Recommended Streamer: fortyone, Score: 18.99
# User 74:
#   Recommended Streamer: itssliker, Score: 14.57
#   Recommended Streamer: greekgodx, Score: 14.25
#   Recommended Streamer: pokelawls, Score: 13.95
# User 6760:
#   Recommended Streamer: xqcow, Score: 15.25
#   Recommended Streamer: xqcow, Score: 15.25
#   Recommended Streamer: barcode_ow, Score: 11.83
# User 97:
#   Recommended Streamer: mitaliang, Score: 14.79
# User 1163:
#   Recommended Streamer: tfue, Score: 0.00
# User 6116:
#   Recommended Streamer: sodapoppin, Score: 21.67
# User 2500:
#   Recommended Streamer: gmhikaru, Score: 11.61
# User 6017:
#   Recommended Streamer: kimdduddi, Score: 7.97
# User 506:
#   Recommended Streamer: itsjstn, Score: 13.92
#   Recommended Streamer: shotz, Score: 12.95
# User 6542:
#   Recommended Streamer: magic, Score: 16.93
#   Recommended Streamer: gunnardota2, Score: 16.92
# User 5823:
#   Recommended Streamer: dogdog, Score: 0.00
# User 909:
#   Recommended Streamer: faceittv, Score: 10.08
# User 4462:
#   Recommended Streamer: summit1g, Score: 11.76
#   Recommended Streamer: sco, Score: 11.59
# User 3772:
#   Recommended Streamer: marcaorx, Score: 14.04
# User 2574:
#   Recommended Streamer: nickmercs, Score: 14.47
#   Recommended Streamer: shroud, Score: 14.35
# User 4231:
#   Recommended Streamer: 10000days, Score: 11.45
# User 7157:
#   Recommended Streamer: purgegamers, Score: 14.38
#   Recommended Streamer: shroud, Score: 14.35
# User 6646:
#   Recommended Streamer: drdisrespect, Score: 0.00
# User 3456:
#   Recommended Streamer: gobgg, Score: 17.18
# User 2736:
#   Recommended Streamer: pokelawls, Score: 14.87
# User 1305:
#   Recommended Streamer: tfue, Score: 20.95
#   Recommended Streamer: eryctriceps, Score: 15.57
#   Recommended Streamer: aydan, Score: 15.28
# User 4627:
#   Recommended Streamer: ninja, Score: 18.96
#   Recommended Streamer: drlupo, Score: 15.33
# User 1246:
#   Recommended Streamer: trainwreckstv, Score: 19.37
# User 1604:
#   Recommended Streamer: maxalibur, Score: 12.04
# User 5194:
#   Recommended Streamer: thijs, Score: 14.96
# User 659:
#   Recommended Streamer: epicenter_en, Score: 12.96
#   Recommended Streamer: btscsgo, Score: 12.29
# User 1825:
#   Recommended Streamer: upsetger, Score: 0.00
# User 3530:
#   Recommended Streamer: buddha, Score: 13.65
#   Recommended Streamer: vader, Score: 11.57
#   Recommended Streamer: bmkibler, Score: 10.94
# User 2760:
#   Recommended Streamer: zerator, Score: 15.02
#   Recommended Streamer: gotaga, Score: 13.39
#   Recommended Streamer: solary, Score: 10.09
# User 5721:
#   Recommended Streamer: tarzaned, Score: 12.85
#   Recommended Streamer: mayahiga, Score: 11.50
# User 3732:
#   Recommended Streamer: hastad, Score: 22.03
#   Recommended Streamer: kneecoleslaw, Score: 17.00
# User 1938:
#   Recommended Streamer: elwind, Score: 14.35
# User 1097:
#   Recommended Streamer: xqcow, Score: 14.13
# User 3638:
#   Recommended Streamer: arthas, Score: 23.94
# User 1900:
#   Recommended Streamer: tfblade, Score: 15.60
# User 137:
#   Recommended Streamer: tfue, Score: 19.73
# User 2426:
#   Recommended Streamer: aydan, Score: 19.71
#   Recommended Streamer: tfue, Score: 15.51
#   Recommended Streamer: fuslie, Score: 14.66
# User 825:
#   Recommended Streamer: knekro, Score: 11.40
# User 1017:
#   Recommended Streamer: summit1g, Score: 13.52
# User 202:
#   Recommended Streamer: jenna, Score: 16.58
# User 6842:
#   Recommended Streamer: jankos, Score: 8.79
#   Recommended Streamer: estilo012, Score: 8.37
# User 2362:
#   Recommended Streamer: pow3rtv, Score: 10.30
# User 1048:
#   Recommended Streamer: timthetatman, Score: 13.14
# User 1686:
#   Recommended Streamer: wkgml, Score: 17.91
# User 1843:
#   Recommended Streamer: svennoss, Score: 11.65
#   Recommended Streamer: x2twins, Score: 10.80
#   Recommended Streamer: mrsavage, Score: 10.06
# User 502:
#   Recommended Streamer: kinggothalion, Score: 10.26
# User 3498:
#   Recommended Streamer: mistafaker, Score: 15.18
# User 1479:
#   Recommended Streamer: 109ace, Score: 21.10
# User 298:
#   Recommended Streamer: rdulive, Score: 14.51
# User 5900:
#   Recommended Streamer: asmongold, Score: 0.00
#   Recommended Streamer: c9sneaky, Score: 0.00
# User 7138:
#   Recommended Streamer: lirik, Score: 15.83
# User 147:
#   Recommended Streamer: nl_kripp, Score: 15.55
#   Recommended Streamer: tsm_hamlinz, Score: 15.24
#   Recommended Streamer: nickmercs, Score: 12.17
# User 6462:
#   Recommended Streamer: tsm_hamlinz, Score: 13.93
#   Recommended Streamer: tsm_myth, Score: 11.17
# User 1377:
#   Recommended Streamer: pwnstarzdotcom, Score: 12.08
# User 7092:
#   Recommended Streamer: lord_kebun, Score: 19.24
# User 3560:
#   Recommended Streamer: jinu6734, Score: 15.24
# User 5727:
#   Recommended Streamer: destiny, Score: 18.12
# User 2539:
#   Recommended Streamer: velion83, Score: 22.56
# User 2490:
#   Recommended Streamer: chekoteh, Score: 14.44
# User 4828:
#   Recommended Streamer: sundayright, Score: 14.29
# User 3567:
#   Recommended Streamer: fortnite, Score: 22.61
#   Recommended Streamer: fortnite, Score: 22.61
#   Recommended Streamer: tfue, Score: 20.42
# User 3396:
#   Recommended Streamer: drdisrespect, Score: 10.83
# User 2136:
#   Recommended Streamer: callofduty, Score: 12.32
# User 7067:
#   Recommended Streamer: tfue, Score: 12.66
#   Recommended Streamer: pate1k, Score: 11.84
# User 823:
#   Recommended Streamer: quickybaby, Score: 12.26
#   Recommended Streamer: shroud, Score: 10.90
# User 1447:
#   Recommended Streamer: elwind, Score: 12.88
#   Recommended Streamer: 404brokenblade, Score: 11.78
# User 5954:
#   Recommended Streamer: sloot, Score: 14.82
# User 2421:
#   Recommended Streamer: linustheafro, Score: 15.01
#   Recommended Streamer: linustheafro, Score: 15.01
# User 5848:
#   Recommended Streamer: tru3ta1ent, Score: 15.24
#   Recommended Streamer: cyr, Score: 14.09
# User 4562:
#   Recommended Streamer: dakotaz, Score: 17.84
# User 1432:
#   Recommended Streamer: tfblade, Score: 11.48
# User 3650:
#   Recommended Streamer: numotthenummy, Score: 0.00
# User 77:
#   Recommended Streamer: csruhub, Score: 10.87
# User 3906:
#   Recommended Streamer: n0thing, Score: 14.66
#   Recommended Streamer: solaryfortnite, Score: 14.42
#   Recommended Streamer: aker_csgo, Score: 14.11
# User 2382:
#   Recommended Streamer: esl_csgo, Score: 15.06
#   Recommended Streamer: blastproseries, Score: 14.49
# User 1185:
#   Recommended Streamer: hitch, Score: 13.93
#   Recommended Streamer: sodapoppin, Score: 12.60
# User 3605:
#   Recommended Streamer: ninja, Score: 13.25
#   Recommended Streamer: tfue, Score: 10.08
# User 5172:
#   Recommended Streamer: callofduty, Score: 12.21
# User 5750:
#   Recommended Streamer: cloakzy, Score: 7.43
#   Recommended Streamer: fortnite, Score: 6.76
# User 7080:
#   Recommended Streamer: methodjosh, Score: 0.00
# User 5404:
#   Recommended Streamer: shaclone, Score: 15.05
# User 5334:
#   Recommended Streamer: ninja, Score: 18.73
# User 464:
#   Recommended Streamer: lirik, Score: 14.99
#   Recommended Streamer: hasanabi, Score: 14.92
#   Recommended Streamer: timthetatman, Score: 14.48
# User 2821:
#   Recommended Streamer: summit1g, Score: 16.94
# User 3424:
#   Recommended Streamer: xayoo_, Score: 14.32
#   Recommended Streamer: parisplatynov, Score: 13.97
# User 3139:
#   Recommended Streamer: kingrichard, Score: 12.10
# User 2630:
#   Recommended Streamer: xchocobars, Score: 11.76
# User 2378:
#   Recommended Streamer: dakotaz, Score: 14.62
# User 3740:
#   Recommended Streamer: midbeast, Score: 14.68
# User 5380:
#   Recommended Streamer: archangel_hs, Score: 17.38
# User 5696:
#   Recommended Streamer: rainbow6, Score: 5.07
#   Recommended Streamer: pengu, Score: 4.85
#   Recommended Streamer: dizzykitten, Score: 4.71
# User 3021:
#   Recommended Streamer: lexveldhuis, Score: 14.21
# User 1947:
#   Recommended Streamer: naowh, Score: 26.66
# User 7014:
#   Recommended Streamer: immortoru, Score: 4.35
#   Recommended Streamer: kendinemuzisyen, Score: 4.12
# User 4392:
#   Recommended Streamer: shroud, Score: 11.71
# User 1380:
#   Recommended Streamer: castro_1021, Score: 14.64
# User 4196:
#   Recommended Streamer: pokimane, Score: 0.00
# User 1136:
#   Recommended Streamer: ghostrecon, Score: 18.41
# User 296:
#   Recommended Streamer: wasuezqelusia, Score: 15.82
# User 6418:
#   Recommended Streamer: koil, Score: 12.94
#   Recommended Streamer: forsen, Score: 11.84
# User 4992:
#   Recommended Streamer: xqcow, Score: 13.69
#   Recommended Streamer: xqcow, Score: 13.69
#   Recommended Streamer: xqcow, Score: 13.69
# User 1857:
#   Recommended Streamer: m0e_tv, Score: 14.18
# User 511:
#   Recommended Streamer: s1mple, Score: 11.55
# User 4940:
#   Recommended Streamer: cherrypach, Score: 11.91
# User 348:
#   Recommended Streamer: jukes, Score: 0.00
# User 2798:
#   Recommended Streamer: symfuhny, Score: 22.06
#   Recommended Streamer: nickmercs, Score: 17.81
# User 6738:
#   Recommended Streamer: shroud, Score: 14.20
# User 1800:
#   Recommended Streamer: jaomock, Score: 14.62
#   Recommended Streamer: chap, Score: 11.82
# User 2887:
#   Recommended Streamer: nmplol, Score: 15.80
# User 1930:
#   Recommended Streamer: gamesdonequick, Score: 11.67
# User 2813:
#   Recommended Streamer: staysafetv, Score: 13.00
#   Recommended Streamer: katevolved, Score: 12.66
#   Recommended Streamer: sodapoppin, Score: 10.04
# User 3565:
#   Recommended Streamer: chap, Score: 0.00
# User 6664:
#   Recommended Streamer: ninja, Score: 11.66
# User 1103:
#   Recommended Streamer: rajjpatel, Score: 17.11
# User 4701:
#   Recommended Streamer: dota2ruhub, Score: 15.11
#   Recommended Streamer: godhunt, Score: 14.26
# User 6380:
#   Recommended Streamer: arthas, Score: 15.20
# User 2980:
#   Recommended Streamer: shroud, Score: 15.87
# User 2119:
#   Recommended Streamer: dakotaz, Score: 20.56
#   Recommended Streamer: liljarvis, Score: 17.76
# User 821:
#   Recommended Streamer: nickmercs, Score: 15.24
# User 6788:
#   Recommended Streamer: admiralbulldog, Score: 15.78
# User 297:
#   Recommended Streamer: gabepeixe, Score: 19.92
# User 3223:
#   Recommended Streamer: dota2mc_ru, Score: 18.34
# User 1719:
#   Recommended Streamer: mymtumtum69, Score: 14.34
# User 4417:
#   Recommended Streamer: ninja, Score: 12.09
# User 6265:
#   Recommended Streamer: solaryfortnite, Score: 16.81
# User 1965:
#   Recommended Streamer: ml7_ow, Score: 2.28
# User 4749:
#   Recommended Streamer: kyle, Score: 13.39
# User 4074:
#   Recommended Streamer: rush, Score: 15.17
#   Recommended Streamer: hashinshin, Score: 14.19
#   Recommended Streamer: metaphor, Score: 13.93
# User 4922:
#   Recommended Streamer: nl_kripp, Score: 18.07
# User 3158:
#   Recommended Streamer: maximilian_dood, Score: 17.87
#   Recommended Streamer: yassuo, Score: 13.26
# User 2729:
#   Recommended Streamer: sodapoppin, Score: 15.38
# User 3988:
#   Recommended Streamer: daltoosh, Score: 11.40
# User 1445:
#   Recommended Streamer: quin69, Score: 11.25
# User 3856:
#   Recommended Streamer: playhearthstone, Score: 19.40
# User 2191:
#   Recommended Streamer: gorgc, Score: 20.88
# User 2932:
#   Recommended Streamer: asmongold, Score: 17.61
# User 5304:
#   Recommended Streamer: benjyfishy, Score: 14.92
# User 2693:
#   Recommended Streamer: cloakzy, Score: 0.00
#   Recommended Streamer: castro_1021, Score: 0.00
# User 5222:
#   Recommended Streamer: dakotaz, Score: 13.62
#   Recommended Streamer: x2twins, Score: 12.46
#   Recommended Streamer: mongraal, Score: 12.10
# User 6679:
#   Recommended Streamer: hanryang1125, Score: 0.00
#   Recommended Streamer: 2chamcham2, Score: 0.00
# User 260:
#   Recommended Streamer: numotthenummy, Score: 14.35
#   Recommended Streamer: grandpoobear, Score: 14.09
# User 3408:
#   Recommended Streamer: superjj102, Score: 11.67
# User 1665:
#   Recommended Streamer: yoda, Score: 13.46
# User 4470:
#   Recommended Streamer: natehill, Score: 10.98
# User 2628:
#   Recommended Streamer: gosu, Score: 5.31
# User 1868:
#   Recommended Streamer: mxey, Score: 0.00
# User 14:
#   Recommended Streamer: weiwei610, Score: 0.00
# User 4467:
#   Recommended Streamer: kinggeorgetv, Score: 14.27
#   Recommended Streamer: break, Score: 12.90
# User 5255:
#   Recommended Streamer: tfue, Score: 0.00
# User 816:
#   Recommended Streamer: methodjosh, Score: 11.01
# User 4530:
#   Recommended Streamer: shaclone, Score: 14.23
# User 1085:
#   Recommended Streamer: mastersnakou, Score: 17.66
# User 2171:
#   Recommended Streamer: rhdgurwns, Score: 10.39
# User 6159:
#   Recommended Streamer: tfue, Score: 14.53
#   Recommended Streamer: vader, Score: 14.40
# User 901:
#   Recommended Streamer: elwind, Score: 12.21
# User 4917:
#   Recommended Streamer: silvername, Score: 14.80
#   Recommended Streamer: versuta, Score: 11.60
#   Recommended Streamer: shroud, Score: 11.22
# User 6026:
#   Recommended Streamer: bladeboques, Score: 14.44
# User 5678:
#   Recommended Streamer: shroud, Score: 13.50
# User 5185:
#   Recommended Streamer: esl_csgo, Score: 12.95
#   Recommended Streamer: rush, Score: 11.87
# User 281:
#   Recommended Streamer: airwisbts, Score: 12.53
# User 4688:
#   Recommended Streamer: liljarvis, Score: 15.46
# User 6748:
#   Recommended Streamer: nicewigg, Score: 12.89
# User 6948:
#   Recommended Streamer: masteerxd, Score: 10.60
# User 6254:
#   Recommended Streamer: itshafu, Score: 12.66
# User 2771:
#   Recommended Streamer: stray228, Score: 15.47
# User 5526:
#   Recommended Streamer: fightincowboy, Score: 14.89
#   Recommended Streamer: maciejay, Score: 14.39
#   Recommended Streamer: cohhcarnage, Score: 11.67
# User 6890:
#   Recommended Streamer: karasmai, Score: 17.61
#   Recommended Streamer: riotgames, Score: 14.42
# User 4780:
#   Recommended Streamer: shroud, Score: 14.75
# User 6909:
#   Recommended Streamer: paoloidolo, Score: 14.33
# User 5891:
#   Recommended Streamer: nymn, Score: 19.54
# User 5873:
#   Recommended Streamer: sodapoppin, Score: 20.74
#   Recommended Streamer: esl_csgo, Score: 11.79
# User 4047:
#   Recommended Streamer: beeftipsy, Score: 14.67
# User 6140:
#   Recommended Streamer: immortoru, Score: 2.51
# User 6720:
#   Recommended Streamer: steelohs, Score: 16.38
# User 2341:
#   Recommended Streamer: solaryhs, Score: 19.91
# User 6699:
#   Recommended Streamer: ninja, Score: 14.32
# User 4167:
#   Recommended Streamer: waveigl, Score: 13.76
# User 6587:
#   Recommended Streamer: madien, Score: 12.01
# User 7035:
#   Recommended Streamer: zeekxd, Score: 11.75
# User 5015:
#   Recommended Streamer: tfue, Score: 19.60
#   Recommended Streamer: ricegum, Score: 17.44
# User 1764:
#   Recommended Streamer: nokss68, Score: 14.24
# User 3908:
#   Recommended Streamer: teepee, Score: 18.05
# User 7066:
#   Recommended Streamer: polt, Score: 11.62
# User 1284:
#   Recommended Streamer: yassuo, Score: 0.00
#   Recommended Streamer: yassuo, Score: 0.00
# User 7117:
#   Recommended Streamer: scarra, Score: 13.68
#   Recommended Streamer: scarra, Score: 13.68
#   Recommended Streamer: pokelawls, Score: 12.05
# User 6657:
#   Recommended Streamer: dota2mc_ru, Score: 14.78
# User 5300:
#   Recommended Streamer: steelohs, Score: 13.10
#   Recommended Streamer: yapyap30, Score: 12.29
#   Recommended Streamer: zilioner, Score: 12.14
# User 634:
#   Recommended Streamer: tipsoutbaby, Score: 15.03
#   Recommended Streamer: sivhd, Score: 14.06
#   Recommended Streamer: methodjosh, Score: 13.70
# User 4295:
#   Recommended Streamer: cowsep, Score: 17.23
#   Recommended Streamer: yassuo, Score: 14.68
# User 5044:
#   Recommended Streamer: scrubnoob, Score: 11.80
#   Recommended Streamer: ratirl, Score: 11.73
# User 7129:
#   Recommended Streamer: nickmercs, Score: 13.54
#   Recommended Streamer: playhearthstone, Score: 13.02
# User 5656:
#   Recommended Streamer: sardoche, Score: 12.73
# User 6676:
#   Recommended Streamer: lord_kebun, Score: 14.62
# User 5344:
#   Recommended Streamer: harbleu, Score: 14.90
# User 516:
#   Recommended Streamer: chriskeem, Score: 22.76
#   Recommended Streamer: mrsavage, Score: 19.93
# User 4016:
#   Recommended Streamer: elraenn, Score: 12.99
# User 6221:
#   Recommended Streamer: disguisedtoast, Score: 15.07
#   Recommended Streamer: febbydoto, Score: 13.81
# User 75:
#   Recommended Streamer: nightblue3, Score: 22.65
# User 2163:
#   Recommended Streamer: pow3rtv, Score: 14.91
# User 4543:
#   Recommended Streamer: yaheljr, Score: 17.77
# User 5329:
#   Recommended Streamer: moonmoon_ow, Score: 23.81
#   Recommended Streamer: kragiee, Score: 23.12
# User 6484:
#   Recommended Streamer: sjow, Score: 12.25
# User 4046:
#   Recommended Streamer: mrsavage, Score: 17.32
# User 6393:
#   Recommended Streamer: mrsavage, Score: 16.67
# User 6750:
#   Recommended Streamer: ewroon, Score: 14.33
# User 229:
#   Recommended Streamer: forsen, Score: 16.52
# User 5875:
#   Recommended Streamer: blondiewondie, Score: 11.57
# User 2046:
#   Recommended Streamer: lord_kebun, Score: 15.03
#   Recommended Streamer: koil, Score: 10.15
# User 4823:
#   Recommended Streamer: kephrii, Score: 14.10
# User 3773:
#   Recommended Streamer: overwatchcontenders, Score: 14.22
#   Recommended Streamer: xqcow, Score: 14.13
# User 5035:
#   Recommended Streamer: mrsavage, Score: 14.33
#   Recommended Streamer: aydan, Score: 11.88
# User 6811:
#   Recommended Streamer: fl0m, Score: 14.19
# User 1795:
#   Recommended Streamer: riotgames, Score: 16.25
#   Recommended Streamer: riotgames, Score: 16.25
# User 6378:
#   Recommended Streamer: fortnite, Score: 12.97
# User 4029:
#   Recommended Streamer: nixjke, Score: 12.17
#   Recommended Streamer: qsnake, Score: 10.94
# User 3352:
#   Recommended Streamer: viperdemon, Score: 11.96
# User 1579:
#   Recommended Streamer: dogdog, Score: 18.26
#   Recommended Streamer: 1pvcs, Score: 11.68
#   Recommended Streamer: izakooo, Score: 11.25
# User 5990:
#   Recommended Streamer: buddha, Score: 14.79
#   Recommended Streamer: summit1g, Score: 13.87
#   Recommended Streamer: timmac, Score: 11.73
# User 3549:
#   Recommended Streamer: terenas, Score: 11.71
# User 3918:
#   Recommended Streamer: naru, Score: 13.13
# User 2848:
#   Recommended Streamer: looksam, Score: 15.70
# User 6006:
#   Recommended Streamer: lord_kebun, Score: 14.99
# User 3702:
#   Recommended Streamer: lebouseuh, Score: 13.33
# User 1516:
#   Recommended Streamer: nightblue3, Score: 14.57
# User 828:
#   Recommended Streamer: c9sneaky, Score: 17.94
#   Recommended Streamer: pokimane, Score: 15.53
# User 2149:
#   Recommended Streamer: chocotaco, Score: 21.30
#   Recommended Streamer: nickmercs, Score: 17.27
# User 6974:
#   Recommended Streamer: maximilian_dood, Score: 12.63
# User 2182:
#   Recommended Streamer: barboysa, Score: 2.86
# User 2201:
#   Recommended Streamer: carljrtm, Score: 12.78
#   Recommended Streamer: lestream, Score: 10.06
# User 848:
#   Recommended Streamer: fl0m, Score: 16.93
#   Recommended Streamer: dreamhackcs, Score: 13.25
# User 6572:
#   Recommended Streamer: welovegames, Score: 17.62
# User 6628:
#   Recommended Streamer: chocotaco, Score: 15.24
# User 3665:
#   Recommended Streamer: lol_madlife, Score: 12.57
# User 5647:
#   Recommended Streamer: tobiasfate, Score: 12.23
# User 5722:
#   Recommended Streamer: greekgodx, Score: 18.88
#   Recommended Streamer: greekgodx, Score: 18.88
#   Recommended Streamer: buddha, Score: 18.65
# User 5985:
#   Recommended Streamer: cloakzy, Score: 7.29
#   Recommended Streamer: mrsavage, Score: 4.59
# User 4563:
#   Recommended Streamer: epicenter_en, Score: 16.56
#   Recommended Streamer: anthonyz, Score: 15.02
# User 6348:
#   Recommended Streamer: domingo, Score: 0.00
# User 6101:
#   Recommended Streamer: lord_kebun, Score: 16.64
#   Recommended Streamer: symfuhny, Score: 11.43
# User 45:
#   Recommended Streamer: defconntv, Score: 15.45
#   Recommended Streamer: overwatchleague, Score: 14.26
# User 7094:
#   Recommended Streamer: sodapoppin, Score: 15.15
# User 957:
#   Recommended Streamer: drunkenheadshot, Score: 14.27
# User 2387:
#   Recommended Streamer: nickmercs, Score: 0.00
# User 4569:
#   Recommended Streamer: kamolrf, Score: 14.84
# User 2071:
#   Recommended Streamer: datmodz, Score: 9.12
# User 5502:
#   Recommended Streamer: swifty, Score: 14.29
# User 4865:
#   Recommended Streamer: miltontpike1, Score: 14.47
# User 837:
#   Recommended Streamer: sodapoppin, Score: 11.38
# User 3973:
#   Recommended Streamer: faker, Score: 11.52
# User 321:
#   Recommended Streamer: tfue, Score: 15.47
#   Recommended Streamer: yougelly, Score: 14.38
#   Recommended Streamer: tsm_hamlinz, Score: 13.44
# User 4365:
#   Recommended Streamer: mrsavage, Score: 11.99
# User 1655:
#   Recommended Streamer: elementlolz, Score: 15.12
# User 6902:
#   Recommended Streamer: socio2k, Score: 14.27
# User 3716:
#   Recommended Streamer: xewer, Score: 18.88
#   Recommended Streamer: gotaga, Score: 11.79
# User 5460:
#   Recommended Streamer: jltomy, Score: 14.68
# User 2929:
#   Recommended Streamer: sam1268, Score: 15.09
# User 3832:
#   Recommended Streamer: timthetatman, Score: 12.84
# User 1195:
#   Recommended Streamer: lumi, Score: 11.25
# User 731:
#   Recommended Streamer: dakotaz, Score: 15.65
#   Recommended Streamer: boss_cr, Score: 14.31
#   Recommended Streamer: sylon, Score: 12.39
# User 1184:
#   Recommended Streamer: berticuss, Score: 14.33
# User 362:
#   Recommended Streamer: imaqtpie, Score: 12.26
# User 6833:
#   Recommended Streamer: fortnite, Score: 14.59
# User 3942:
#   Recommended Streamer: tidesoftime, Score: 18.54
#   Recommended Streamer: sivhd, Score: 16.99
# User 6938:
#   Recommended Streamer: jahrein, Score: 0.00
# User 2274:
#   Recommended Streamer: eryctriceps, Score: 14.75
#   Recommended Streamer: drlupo, Score: 14.36
# User 4102:
#   Recommended Streamer: gratis150ml, Score: 20.35
# User 7137:
#   Recommended Streamer: fortnite, Score: 15.79
# User 2148:
#   Recommended Streamer: ninja, Score: 21.28
#   Recommended Streamer: drlupo, Score: 18.30
# User 2946:
#   Recommended Streamer: moonmoon_ow, Score: 13.65
# User 6440:
#   Recommended Streamer: drlupo, Score: 19.65
#   Recommended Streamer: aydan, Score: 15.89
#   Recommended Streamer: tsm_hamlinz, Score: 13.82
# User 3531:
#   Recommended Streamer: mastertay, Score: 14.44
# User 5039:
#   Recommended Streamer: esfandtv, Score: 11.84
# User 6406:
#   Recommended Streamer: jankos, Score: 11.88
#   Recommended Streamer: ziqoftw, Score: 11.38
# User 6525:
#   Recommended Streamer: tsm_myth, Score: 13.87
# User 3301:
#   Recommended Streamer: csruhub2, Score: 13.83
# User 7064:
#   Recommended Streamer: ibiza, Score: 12.07
# User 2649:
#   Recommended Streamer: faker, Score: 15.75
#   Recommended Streamer: mongraal, Score: 10.28
#   Recommended Streamer: riotgames, Score: 10.01
# User 534:
#   Recommended Streamer: rubius, Score: 14.75
# User 6194:
#   Recommended Streamer: maryjleeee, Score: 17.14
# User 956:
#   Recommended Streamer: boxbox, Score: 14.40
# User 6810:
#   Recommended Streamer: mrsavage, Score: 10.00
# User 3007:
#   Recommended Streamer: kaleahkay, Score: 14.13
# User 5741:
#   Recommended Streamer: hexy, Score: 16.44
# User 6345:
#   Recommended Streamer: trainwreckstv, Score: 15.50
# User 3132:
#   Recommended Streamer: ashlynn, Score: 13.19
#   Recommended Streamer: lord_kebun, Score: 10.07
# User 4232:
#   Recommended Streamer: gotaga, Score: 24.79
# User 3493:
#   Recommended Streamer: mayahiga, Score: 11.25
# User 270:
#   Recommended Streamer: shroud, Score: 17.55
# User 7084:
#   Recommended Streamer: tfue, Score: 14.53
#   Recommended Streamer: pokimane, Score: 14.44
# User 2144:
#   Recommended Streamer: dakotaz, Score: 19.03
# User 1504:
#   Recommended Streamer: saddummy, Score: 14.70
# User 149:
#   Recommended Streamer: ruukialol, Score: 14.50
#   Recommended Streamer: ogataju, Score: 14.44
# User 3585:
#   Recommended Streamer: rhdgurwns, Score: 14.41
# User 6567:
#   Recommended Streamer: symfuhny, Score: 12.29
# User 1742:
#   Recommended Streamer: loeya, Score: 17.86
# User 4683:
#   Recommended Streamer: solaryfortnite, Score: 14.42
#   Recommended Streamer: solaryfortnite, Score: 14.42
# User 458:
#   Recommended Streamer: ziggy, Score: 21.73
# User 992:
#   Recommended Streamer: moonmoon_ow, Score: 17.36
#   Recommended Streamer: lord_kebun, Score: 14.48
# User 5576:
#   Recommended Streamer: dota2ruhub, Score: 12.61
#   Recommended Streamer: h0bbitzce, Score: 11.78
# User 2112:
#   Recommended Streamer: realkraftyy, Score: 12.08
# User 4460:
#   Recommended Streamer: khezu, Score: 13.17
#   Recommended Streamer: gorgc, Score: 11.12
# User 1007:
#   Recommended Streamer: diegosaurs, Score: 12.13
#   Recommended Streamer: stray228, Score: 11.39
# User 5265:
#   Recommended Streamer: dreamhackcs, Score: 21.04
# User 4427:
#   Recommended Streamer: bratishkinoff, Score: 14.15
# User 983:
#   Recommended Streamer: alanzoka, Score: 10.90
# User 2069:
#   Recommended Streamer: kaceytron, Score: 12.21
# User 2011:
#   Recommended Streamer: fluttenlf, Score: 0.00
# User 4055:
#   Recommended Streamer: cocopopp671, Score: 20.70
# User 1566:
#   Recommended Streamer: leffen, Score: 19.76
#   Recommended Streamer: esfandtv, Score: 19.70
# User 2199:
#   Recommended Streamer: disguisedtoast, Score: 12.48
# User 2496:
#   Recommended Streamer: summit1g, Score: 19.14
#   Recommended Streamer: reckful, Score: 13.00
# User 5949:
#   Recommended Streamer: scripe, Score: 14.20
#   Recommended Streamer: methodjosh, Score: 11.00
# User 556:
#   Recommended Streamer: wtcn, Score: 13.26
#   Recommended Streamer: levo, Score: 12.25
# User 6773:
#   Recommended Streamer: 7ssk7, Score: 17.22
# User 1392:
#   Recommended Streamer: g2perkz, Score: 11.98
#   Recommended Streamer: alliestrasza, Score: 11.71
# User 6577:
#   Recommended Streamer: a1taoda, Score: 17.52
#   Recommended Streamer: xgladd, Score: 17.44
# User 2181:
#   Recommended Streamer: happasc2, Score: 14.38
# User 829:
#   Recommended Streamer: tfblade, Score: 12.05
# User 5332:
#   Recommended Streamer: solaryfortnite, Score: 10.02
# User 338:
#   Recommended Streamer: riotgames, Score: 14.44
# User 3591:
#   Recommended Streamer: greekgodx, Score: 12.34
# User 3516:
#   Recommended Streamer: pokelawls, Score: 20.00
#   Recommended Streamer: xqcow, Score: 19.05
# User 6273:
#   Recommended Streamer: dakotaz, Score: 15.90
#   Recommended Streamer: sypherpk, Score: 13.60
# User 5835:
#   Recommended Streamer: juliettearz, Score: 11.83
#   Recommended Streamer: ninja, Score: 11.52
# User 5682:
#   Recommended Streamer: bmkibler, Score: 19.47
# User 2322:
#   Recommended Streamer: yassuo, Score: 14.97
# User 2728:
#   Recommended Streamer: s1mple, Score: 13.94
# User 2154:
#   Recommended Streamer: gafallen, Score: 0.00
#   Recommended Streamer: drlupo, Score: 0.00
#   Recommended Streamer: kingrichard, Score: 0.00
# User 3972:
#   Recommended Streamer: iwilldominate, Score: 18.91
# User 7145:
#   Recommended Streamer: jukes, Score: 12.77
# User 3518:
#   Recommended Streamer: rammus53, Score: 11.76
# User 970:
#   Recommended Streamer: boyminoru, Score: 17.74
# User 5939:
#   Recommended Streamer: tfblade, Score: 13.94
#   Recommended Streamer: zade, Score: 11.74
# User 3614:
#   Recommended Streamer: faker, Score: 14.33
# User 4756:
#   Recommended Streamer: dafran, Score: 12.06
# User 6163:
#   Recommended Streamer: gotaga, Score: 12.23
# User 3765:
#   Recommended Streamer: superjj102, Score: 10.62
# User 6835:
#   Recommended Streamer: espnesports, Score: 13.77
#   Recommended Streamer: gorgc, Score: 11.31
# User 3058:
#   Recommended Streamer: mrfreshasian, Score: 18.03
# User 2078:
#   Recommended Streamer: manyrin, Score: 0.00
#   Recommended Streamer: blackufa, Score: 0.00
# User 5229:
#   Recommended Streamer: moonmoon_ow, Score: 28.48
# User 5148:
#   Recommended Streamer: cyr, Score: 14.29
# User 47:
#   Recommended Streamer: anthonyz, Score: 11.33
# User 2180:
#   Recommended Streamer: snip3down, Score: 12.03
# User 307:
#   Recommended Streamer: lirik, Score: 10.18
# User 333:
#   Recommended Streamer: gorgc, Score: 10.37
# User 3016:
#   Recommended Streamer: iamdiamond, Score: 12.51
# User 2542:
#   Recommended Streamer: thijs, Score: 22.94
# User 5916:
#   Recommended Streamer: joshog, Score: 15.96
# User 2131:
#   Recommended Streamer: aphromoo, Score: 11.96
#   Recommended Streamer: senfglas_, Score: 11.53
#   Recommended Streamer: nl_kripp, Score: 10.00
# User 676:
#   Recommended Streamer: gotaga, Score: 13.80
# User 3469:
#   Recommended Streamer: gohamedia, Score: 12.12
# User 4818:
#   Recommended Streamer: vgbootcamp, Score: 15.03
# User 3670:
#   Recommended Streamer: koil, Score: 19.64
# User 3454:
#   Recommended Streamer: amouranth, Score: 13.14
# User 4500:
#   Recommended Streamer: esl_csgo, Score: 11.93
#   Recommended Streamer: grimmmz, Score: 11.86
# User 6585:
#   Recommended Streamer: tfue, Score: 14.82
# User 3364:
#   Recommended Streamer: cigarettestv, Score: 17.72
# User 6698:
#   Recommended Streamer: garenatw, Score: 23.53
# User 5587:
#   Recommended Streamer: dakotaz, Score: 15.84
# User 6812:
#   Recommended Streamer: jackspektra, Score: 19.94
# User 3744:
#   Recommended Streamer: cizzorz, Score: 11.51
#   Recommended Streamer: aydan, Score: 10.99
#   Recommended Streamer: ninja, Score: 10.08
# User 6000:
#   Recommended Streamer: vader, Score: 10.02
# User 1539:
#   Recommended Streamer: methodjosh, Score: 12.82
# User 1546:
#   Recommended Streamer: tsm_hamlinz, Score: 13.90
#   Recommended Streamer: drlupo, Score: 10.07
#   Recommended Streamer: drlupo, Score: 10.07
# User 2376:
#   Recommended Streamer: wlswnwlswn, Score: 14.12
# User 6636:
#   Recommended Streamer: blizzard, Score: 12.18
# User 1968:
#   Recommended Streamer: asmongold, Score: 14.69
# User 6815:
#   Recommended Streamer: silerlol, Score: 17.50
# User 3496:
#   Recommended Streamer: arkismall, Score: 11.97
# User 2416:
#   Recommended Streamer: couragejd, Score: 14.00
#   Recommended Streamer: tfue, Score: 13.96
#   Recommended Streamer: fortnite, Score: 13.16
# User 5594:
#   Recommended Streamer: tfue, Score: 13.85
# User 2556:
#   Recommended Streamer: moonmoon_ow, Score: 19.41
# User 2919:
#   Recommended Streamer: shroud, Score: 14.26
# User 789:
#   Recommended Streamer: shiphtur, Score: 22.77
#   Recommended Streamer: ratirl, Score: 20.06
#   Recommended Streamer: yassuo, Score: 18.55
# User 5742:
#   Recommended Streamer: loltyler1, Score: 15.67
# User 2826:
#   Recommended Streamer: amouranth, Score: 11.06
#   Recommended Streamer: elementlolz, Score: 10.75
# User 5953:
#   Recommended Streamer: tjsdjq123, Score: 15.63
# User 4126:
#   Recommended Streamer: ninja, Score: 12.49
# User 5429:
#   Recommended Streamer: admiralbulldog, Score: 19.67
#   Recommended Streamer: gsl, Score: 14.86
# User 3985:
#   Recommended Streamer: solaryfortnite, Score: 15.90
# User 6217:
#   Recommended Streamer: jungtaejune, Score: 22.79
# User 2782:
#   Recommended Streamer: elded, Score: 17.73
# User 5871:
#   Recommended Streamer: vgbootcamp, Score: 14.14
#   Recommended Streamer: tekken, Score: 14.14
#   Recommended Streamer: maximilian_dood, Score: 10.15
# User 5801:
#   Recommended Streamer: alfie, Score: 17.63
# User 3775:
#   Recommended Streamer: dreadztv, Score: 12.27
#   Recommended Streamer: korbanhs, Score: 11.71
#   Recommended Streamer: ybicanoooobov, Score: 11.07
# User 6511:
#   Recommended Streamer: moistcr1tikal, Score: 11.90
# User 2838:
#   Recommended Streamer: fioramech, Score: 14.81
#   Recommended Streamer: hastad, Score: 14.43
# User 5714:
#   Recommended Streamer: nana803, Score: 14.68
#   Recommended Streamer: kyo1984123, Score: 13.60
# User 1889:
#   Recommended Streamer: drlupo, Score: 0.00
# User 1550:
#   Recommended Streamer: nanayango3o, Score: 14.67
# User 2031:
#   Recommended Streamer: tfue, Score: 29.69
#   Recommended Streamer: nickmercs, Score: 23.74
#   Recommended Streamer: reverse2k, Score: 20.29
# User 5837:
#   Recommended Streamer: aydan, Score: 12.72
#   Recommended Streamer: tfue, Score: 11.09
# User 4509:
#   Recommended Streamer: moonmoon_ow, Score: 15.02
#   Recommended Streamer: koil, Score: 14.57
#   Recommended Streamer: wizzrobe, Score: 14.25
# User 222:
#   Recommended Streamer: yoda, Score: 13.46
#   Recommended Streamer: patopapao, Score: 13.38
#   Recommended Streamer: s1mple, Score: 13.19
# User 4667:
#   Recommended Streamer: quin69, Score: 21.35
#   Recommended Streamer: esfandtv, Score: 20.98
# User 6566:
#   Recommended Streamer: admiralbulldog, Score: 23.62
# User 2734:
#   Recommended Streamer: ninja, Score: 11.89
#   Recommended Streamer: dakotaz, Score: 10.07
# User 2472:
#   Recommended Streamer: shroud, Score: 10.05
# User 1481:
#   Recommended Streamer: thedivisiongame, Score: 13.32
# User 6350:
#   Recommended Streamer: garenatw, Score: 15.27
# User 374:
#   Recommended Streamer: ogaminglol, Score: 15.94
# User 434:
#   Recommended Streamer: imaqtpie, Score: 13.06
#   Recommended Streamer: ninja, Score: 11.95
# User 4557:
#   Recommended Streamer: drerhano, Score: 14.32
# User 4430:
#   Recommended Streamer: esl_csgo, Score: 14.21
# User 4040:
#   Recommended Streamer: kitboga, Score: 12.80
# User 3921:
#   Recommended Streamer: looksam, Score: 16.48
# User 5349:
#   Recommended Streamer: gssspotted, Score: 14.42
# User 6122:
#   Recommended Streamer: sodapoppin, Score: 13.54
# User 4827:
#   Recommended Streamer: erobb221, Score: 14.28
#   Recommended Streamer: destiny, Score: 11.14
# User 2829:
#   Recommended Streamer: nickmercs, Score: 16.55
# User 6528:
#   Recommended Streamer: moonmoon_ow, Score: 12.92
#   Recommended Streamer: moonmoon_ow, Score: 12.92
#   Recommended Streamer: drlupo, Score: 12.22
# User 1247:
#   Recommended Streamer: ninja, Score: 16.68
# User 3435:
#   Recommended Streamer: dreamhackcs, Score: 14.21
# User 6067:
#   Recommended Streamer: fearitself, Score: 10.70
# User 5595:
#   Recommended Streamer: ludwigahgren, Score: 16.80
#   Recommended Streamer: armadaugs, Score: 14.59
# User 4995:
#   Recommended Streamer: cloakzy, Score: 12.01
# User 2115:
#   Recommended Streamer: evelone192, Score: 10.90
# User 2688:
#   Recommended Streamer: sodapoppin, Score: 17.40
# User 4640:
#   Recommended Streamer: suanetty, Score: 23.68
#   Recommended Streamer: wasuezqelusia, Score: 23.11
# User 2938:
#   Recommended Streamer: shroud, Score: 15.44
# User 6714:
#   Recommended Streamer: www0606, Score: 12.36
# User 3162:
#   Recommended Streamer: lestream, Score: 10.08
#   Recommended Streamer: lestream, Score: 10.08
# User 6983:
#   Recommended Streamer: mickalow, Score: 13.61
# User 1746:
#   Recommended Streamer: sodapoppin, Score: 18.30
#   Recommended Streamer: forsen, Score: 13.71
#   Recommended Streamer: asmongold, Score: 13.27
# User 6343:
#   Recommended Streamer: saddummy, Score: 12.10
# User 923:
#   Recommended Streamer: lrojo_, Score: 11.37
# User 6784:
#   Recommended Streamer: mira, Score: 14.76
# User 1375:
#   Recommended Streamer: gosu, Score: 15.32
# User 880:
#   Recommended Streamer: pokelawls, Score: 12.09
#   Recommended Streamer: stormen, Score: 11.48
# User 456:
#   Recommended Streamer: admiralbahroo, Score: 18.51
# User 191:
#   Recommended Streamer: xqcow, Score: 20.32
# User 3654:
#   Recommended Streamer: ninja, Score: 13.28
# User 3296:
#   Recommended Streamer: loltyler1, Score: 11.62
#   Recommended Streamer: 10000days, Score: 11.41
# User 4290:
#   Recommended Streamer: cohhcarnage, Score: 16.50
# User 624:
#   Recommended Streamer: brookeab, Score: 12.91
# User 2527:
#   Recommended Streamer: tfue, Score: 15.39
#   Recommended Streamer: ninja, Score: 15.02
# User 4194:
#   Recommended Streamer: wasuezqelusia, Score: 14.90
# User 2404:
#   Recommended Streamer: nookyyy, Score: 17.17
#   Recommended Streamer: nookyyy, Score: 17.17
# User 4202:
#   Recommended Streamer: zai, Score: 14.19
#   Recommended Streamer: universedota, Score: 12.14
# User 6192:
#   Recommended Streamer: reckful, Score: 12.01
# User 701:
#   Recommended Streamer: riotgames, Score: 16.32
# User 3853:
#   Recommended Streamer: drlupo, Score: 14.36
#   Recommended Streamer: annemunition, Score: 14.24
# User 4005:
#   Recommended Streamer: esl_csgo, Score: 16.25
# User 4795:
#   Recommended Streamer: sodapoppin, Score: 15.86
#   Recommended Streamer: followgrubby, Score: 15.23
# User 5093:
#   Recommended Streamer: dekarldent, Score: 15.31
# User 5365:
#   Recommended Streamer: beyondthesummit, Score: 14.49
#   Recommended Streamer: calebdmtg, Score: 14.11
# User 1884:
#   Recommended Streamer: esl_csgo, Score: 13.15
# User 3145:
#   Recommended Streamer: elwind, Score: 16.31
# User 3114:
#   Recommended Streamer: mrsavage, Score: 14.46
# User 6789:
#   Recommended Streamer: khunaa, Score: 16.39
# User 2747:
#   Recommended Streamer: tfue, Score: 12.05
# User 987:
#   Recommended Streamer: chap, Score: 19.60
# User 6448:
#   Recommended Streamer: esl_csgo, Score: 15.06
#   Recommended Streamer: pinkwardlol, Score: 14.16
#   Recommended Streamer: nba2kleague, Score: 13.94
# User 1974:
#   Recommended Streamer: summit1g, Score: 11.71
# User 2048:
#   Recommended Streamer: ninja, Score: 17.67
#   Recommended Streamer: mrfreshasian, Score: 11.84
# User 3432:
#   Recommended Streamer: zilioner, Score: 19.57
#   Recommended Streamer: 2chamcham2, Score: 18.64
# User 1420:
#   Recommended Streamer: dota2ruhub, Score: 18.93
#   Recommended Streamer: romanovalera, Score: 17.32
# User 4953:
#   Recommended Streamer: maximilian_dood, Score: 14.63
#   Recommended Streamer: overwatchleague, Score: 13.19
# User 3389:
#   Recommended Streamer: asmongold, Score: 29.85
# User 3664:
#   Recommended Streamer: tfue, Score: 14.08
# User 703:
#   Recommended Streamer: symfuhny, Score: 11.72
# User 1615:
#   Recommended Streamer: couragejd, Score: 16.74
# User 5935:
#   Recommended Streamer: shisudotes, Score: 20.24
#   Recommended Streamer: alohadancetv, Score: 17.12
# User 2357:
#   Recommended Streamer: ssaab, Score: 0.00
# User 293:
#   Recommended Streamer: couragejd, Score: 12.41
# User 6638:
#   Recommended Streamer: fps_shaka, Score: 12.24
#   Recommended Streamer: symfuhny, Score: 12.00
# User 3599:
#   Recommended Streamer: tfue, Score: 14.59
# User 5606:
#   Recommended Streamer: gorgc, Score: 22.52
# User 1576:
#   Recommended Streamer: cohhcarnage, Score: 18.65
# User 4247:
#   Recommended Streamer: overwatchleague, Score: 10.54
# User 3497:
#   Recommended Streamer: esl_csgo, Score: 20.13
# User 2714:
#   Recommended Streamer: shroud, Score: 12.40
# User 118:
#   Recommended Streamer: moonmoon_ow, Score: 14.56
#   Recommended Streamer: shroud, Score: 12.36
# User 4175:
#   Recommended Streamer: dreamhackcs, Score: 13.10
# User 6501:
#   Recommended Streamer: tru3ta1ent, Score: 11.41
#   Recommended Streamer: alanzoka, Score: 10.68
# User 639:
#   Recommended Streamer: philza, Score: 14.25
# User 3680:
#   Recommended Streamer: nickmercs, Score: 14.65
# User 4097:
#   Recommended Streamer: asayaart, Score: 14.33
#   Recommended Streamer: godhunt, Score: 14.26
#   Recommended Streamer: rxnexus, Score: 14.20
# User 2762:
#   Recommended Streamer: itshafu, Score: 0.00
#   Recommended Streamer: tidesoftime, Score: 0.00
#   Recommended Streamer: firebat, Score: 0.00
# User 646:
#   Recommended Streamer: timthetatman, Score: 20.17
#   Recommended Streamer: sodapoppin, Score: 12.54
# User 216:
#   Recommended Streamer: esl_csgo, Score: 13.52
#   Recommended Streamer: tfue, Score: 13.06
# User 1529:
#   Recommended Streamer: pajalockk, Score: 14.33
# User 1474:
#   Recommended Streamer: pengu, Score: 14.55
# User 3311:
#   Recommended Streamer: tfblade, Score: 14.13
# User 706:
#   Recommended Streamer: mdldisney, Score: 14.12
# User 4310:
#   Recommended Streamer: tsm_viss, Score: 17.23
#   Recommended Streamer: ch1ckenkun, Score: 12.18
# User 1401:
#   Recommended Streamer: angrypug, Score: 15.81
# User 2948:
#   Recommended Streamer: yassuo, Score: 12.00
#   Recommended Streamer: cognaclol, Score: 11.95
# User 3955:
#   Recommended Streamer: tfue, Score: 11.66
#   Recommended Streamer: tfue, Score: 11.66
# User 1390:
#   Recommended Streamer: pokimane, Score: 21.71
# User 6445:
#   Recommended Streamer: mrnosleep, Score: 14.48
#   Recommended Streamer: alkan, Score: 14.44
#   Recommended Streamer: shroud, Score: 14.35
# User 3624:
#   Recommended Streamer: silikonovayazina, Score: 23.63
#   Recommended Streamer: forsalive, Score: 23.39
# User 3060:
#   Recommended Streamer: overwatchleague, Score: 11.59
# User 2187:
#   Recommended Streamer: gamesdonequick, Score: 11.79
# User 5326:
#   Recommended Streamer: squeezielive, Score: 14.02
# User 69:
#   Recommended Streamer: ninja, Score: 12.46
#   Recommended Streamer: ybicanoooobov, Score: 11.47
# User 4533:
#   Recommended Streamer: dota2ruhub, Score: 12.90
#   Recommended Streamer: drdisrespect, Score: 11.96
# User 5653:
#   Recommended Streamer: fearitself, Score: 14.75
# User 4513:
#   Recommended Streamer: esl_csgo, Score: 14.60
#   Recommended Streamer: timmac, Score: 13.01
# User 4091:
#   Recommended Streamer: havoc616, Score: 12.35
# User 1076:
#   Recommended Streamer: cdnthe3rd, Score: 11.65
# User 5240:
#   Recommended Streamer: faker, Score: 12.52
# User 6197:
#   Recommended Streamer: nana803, Score: 0.00
# User 5614:
#   Recommended Streamer: quin69, Score: 13.88
# User 6257:
#   Recommended Streamer: tsm_myth, Score: 12.15
# User 4559:
#   Recommended Streamer: qsnake, Score: 12.41
# User 5762:
#   Recommended Streamer: jankos, Score: 11.29
# User 2001:
#   Recommended Streamer: jukes, Score: 0.00
# User 6485:
#   Recommended Streamer: symfuhny, Score: 14.42
#   Recommended Streamer: cloakzy, Score: 14.01
# User 6874:
#   Recommended Streamer: riotgames, Score: 11.75
#   Recommended Streamer: 10000days, Score: 10.75
# User 4659:
#   Recommended Streamer: saddummy, Score: 11.94
# User 3085:
#   Recommended Streamer: thedarkness, Score: 13.93
# User 1723:
#   Recommended Streamer: cyanideplaysgames, Score: 12.90
#   Recommended Streamer: solorenektononly, Score: 11.54
# User 3693:
#   Recommended Streamer: cdnthe3rd, Score: 16.99
# User 1384:
#   Recommended Streamer: fortnite, Score: 14.80
# User 6321:
#   Recommended Streamer: lebouseuh, Score: 16.95
# User 6868:
#   Recommended Streamer: forsen, Score: 14.43
# User 3762:
#   Recommended Streamer: overwatchleague, Score: 10.87
# User 4505:
#   Recommended Streamer: ninja, Score: 18.69
# User 5744:
#   Recommended Streamer: mari0712, Score: 22.71
# User 4605:
#   Recommended Streamer: tfue, Score: 14.96
#   Recommended Streamer: ninja, Score: 13.03
# User 1783:
#   Recommended Streamer: mongraal, Score: 14.57
# User 1856:
#   Recommended Streamer: wachinanii, Score: 14.44
# User 5151:
# ...
# User 2550:
#   Recommended Streamer: shroud, Score: 15.18
# User 6894:
#   Recommended Streamer: tenderlybae, Score: 14.41
# User 4660:
#   Recommended Streamer: xqcow, Score: 10.03
# User 239:
#   Recommended Streamer: lolathon, Score: 14.63
# User 5410:
#   Recommended Streamer: naseongkim, Score: 13.86
# User 1300:
#   Recommended Streamer: mews, Score: 11.58
# User 3789:
#   Recommended Streamer: rhdgurwns, Score: 14.41
# User 5123:
#   Recommended Streamer: pietsmiet, Score: 16.02
# User 1891:
#   Recommended Streamer: tfue, Score: 11.40
# User 1394:
#   Recommended Streamer: huahed, Score: 14.56
# User 2936:
#   Recommended Streamer: sodapoppin, Score: 15.28
# User 6259:
#   Recommended Streamer: tarzaned, Score: 21.80
# User 7053:
#   Recommended Streamer: 72hrs, Score: 16.39
# User 3361:
#   Recommended Streamer: suanetty, Score: 12.74
# User 3505:
#   Recommended Streamer: pokimane, Score: 17.21
# User 1754:
#   Recommended Streamer: mr_mammal, Score: 14.31
# User 5825:
#   Recommended Streamer: dansgaming, Score: 11.91
# User 4521:
#   Recommended Streamer: xqcow, Score: 12.24
# User 2743:
#   Recommended Streamer: poach, Score: 17.17
# User 2482:
#   Recommended Streamer: srdplay, Score: 14.25
# User 231:
#   Recommended Streamer: tfblade, Score: 10.83
# User 2435:
#   Recommended Streamer: kamolrf, Score: 13.12
# User 4909:
#   Recommended Streamer: psiconewz, Score: 14.67
# User 355:
#   Recommended Streamer: btscsgo, Score: 20.76
# User 3366:
#   Recommended Streamer: rhdgurwns, Score: 17.30
# User 6515:
#   Recommended Streamer: jovirone, Score: 19.89
#   Recommended Streamer: axtlol, Score: 19.20
# User 5608:
#   Recommended Streamer: lapi, Score: 15.62
# User 1326:
#   Recommended Streamer: amouranth, Score: 13.69
# User 7112:
#   Recommended Streamer: dakotaz, Score: 12.52
# User 1084:
#   Recommended Streamer: zerator, Score: 15.70
# User 2881:
#   Recommended Streamer: sardoche, Score: 13.41
# User 931:
#   Recommended Streamer: dota2ruhub2, Score: 12.18
# User 753:
#   Recommended Streamer: mendokusaii, Score: 13.89
# User 2832:
#   Recommended Streamer: tfblade, Score: 6.29
# User 2253:
#   Recommended Streamer: qrushcsgo, Score: 12.72
# User 2162:
#   Recommended Streamer: moondye7, Score: 17.33
# User 4323:
#   Recommended Streamer: karasmai, Score: 15.77
# User 3115:
#   Recommended Streamer: chap, Score: 10.03
# User 3503:
#   Recommended Streamer: holyphoenix, Score: 10.67
# User 1824:
#   Recommended Streamer: gonedoc, Score: 12.23
# User 2445:
#   Recommended Streamer: faker, Score: 11.51
# User 4549:
#   Recommended Streamer: tenderlybae, Score: 14.68
# User 1762:
#   Recommended Streamer: dota2ruhub, Score: 12.63
# User 2488:
#   Recommended Streamer: mrsavage, Score: 12.49
# User 1198:
#   Recommended Streamer: shotz, Score: 22.56
#   Recommended Streamer: lord_kebun, Score: 22.09
# User 2811:
#   Recommended Streamer: dota2ruhub, Score: 13.00
# User 3535:
#   Recommended Streamer: 72hrs, Score: 0.00
#   Recommended Streamer: fortnite, Score: 0.00
# User 4758:
#   Recommended Streamer: forsen, Score: 10.83
# User 212:
#   Recommended Streamer: bazattak007, Score: 14.28
# User 2911:
#   Recommended Streamer: riotgames, Score: 12.44
# User 617:
#   Recommended Streamer: domingo, Score: 16.97
# User 5217:
#   Recommended Streamer: kabajiow, Score: 14.01
# User 2611:
#   Recommended Streamer: honeybeecommandeur, Score: 14.27
# User 819:
#   Recommended Streamer: sivhd, Score: 13.31
# User 3206:
#   Recommended Streamer: vgbootcamp, Score: 20.57
# User 2273:
#   Recommended Streamer: playstation, Score: 13.91
# User 2828:
#   Recommended Streamer: summit1g, Score: 15.20
# User 650:
#   Recommended Streamer: toyzttv, Score: 23.56
# User 2206:
#   Recommended Streamer: moonmoon_ow, Score: 16.41
# User 3083:
#   Recommended Streamer: fortnite, Score: 12.75
# User 4916:
#   Recommended Streamer: overpow, Score: 14.89
# User 6032:
#   Recommended Streamer: brookeab, Score: 14.94
# User 5178:
#   Recommended Streamer: handongsuk, Score: 23.54
# User 7118:
#   Recommended Streamer: method, Score: 15.89
# User 739:
#   Recommended Streamer: maximilian_dood, Score: 29.50
# User 164:
#   Recommended Streamer: aydan, Score: 10.45
# User 864:
#   Recommended Streamer: symfuhny, Score: 18.84
# User 813:
#   Recommended Streamer: tfue, Score: 13.08
# User 4200:
#   Recommended Streamer: yassuo, Score: 0.00
# User 203:
#   Recommended Streamer: polt, Score: 11.39
# User 3553:
#   Recommended Streamer: tsm_viss, Score: 15.10
# User 4313:
#   Recommended Streamer: kiiper0ne, Score: 0.00
# User 225:
#   Recommended Streamer: iamdiamond, Score: 13.51
# User 2440:
#   Recommended Streamer: mister903, Score: 23.08
#   Recommended Streamer: saddummy, Score: 21.98
# User 3362:
#   Recommended Streamer: yassuo, Score: 12.32
#   Recommended Streamer: gafallen, Score: 11.52
# User 2392:
#   Recommended Streamer: innocents, Score: 14.55
# User 6045:
#   Recommended Streamer: kabajiow, Score: 12.41
# User 2581:
#   Recommended Streamer: polt, Score: 13.97
# User 788:
#   Recommended Streamer: purple_hs, Score: 24.44
# User 5499:
#   Recommended Streamer: handongsuk, Score: 12.29
# User 128:
#   Recommended Streamer: domingo, Score: 17.44
# User 3697:
#   Recommended Streamer: sypherpk, Score: 11.80
# User 1654:
#   Recommended Streamer: magic, Score: 16.52
# User 4881:
#   Recommended Streamer: delordione, Score: 15.64
# User 7044:
#   Recommended Streamer: markilokurasy, Score: 11.87
# User 1540:
#   Recommended Streamer: hwkang2, Score: 11.47
# User 277:
#   Recommended Streamer: honeymad, Score: 10.52
# User 4260:
#   Recommended Streamer: hanryang1125, Score: 13.51
# User 1039:
#   Recommended Streamer: yassuo, Score: 14.58
# User 4797:
#   Recommended Streamer: holyphoenix, Score: 14.47
# User 492:
#   Recommended Streamer: tfue, Score: 21.69
# User 269:
#   Recommended Streamer: zerator, Score: 14.82
# User 4791:
#   Recommended Streamer: asmodaitv, Score: 14.50
# User 5028:
#   Recommended Streamer: tfblade, Score: 3.69
# User 2200:
#   Recommended Streamer: rammus53, Score: 14.00
# User 5160:
#   Recommended Streamer: sardoche, Score: 14.16
# User 3407:
#   Recommended Streamer: niniko_w, Score: 11.85
# User 5084:
#   Recommended Streamer: floe, Score: 17.52
# User 3150:
#   Recommended Streamer: disguisedtoast, Score: 12.46
#   Recommended Streamer: mikasa_th, Score: 12.13
#   Recommended Streamer: gssspotted, Score: 11.38
# User 3410:
#   Recommended Streamer: letsgiveitaspin, Score: 14.29
# User 1687:
#   Recommended Streamer: solaryfortnite, Score: 13.32
# User 5088:
#   Recommended Streamer: shenryyr, Score: 14.16
# User 4354:
#   Recommended Streamer: gorgc, Score: 23.70
# User 2638:
#   Recommended Streamer: reckful, Score: 12.52
# User 3891:
#   Recommended Streamer: summit1g, Score: 10.05
# User 4805:
#   Recommended Streamer: teukka, Score: 14.26
# User 3146:
#   Recommended Streamer: summit1g, Score: 19.77
# User 3473:
#   Recommended Streamer: tfue, Score: 11.39
# User 3584:
#   Recommended Streamer: pepiinero, Score: 11.31
# User 4135:
#   Recommended Streamer: rajjpatel, Score: 13.96
# User 5759:
#   Recommended Streamer: lvpes, Score: 14.94
# User 5067:
#   Recommended Streamer: aktep, Score: 14.29
# User 882:
#   Recommended Streamer: limit_maximum, Score: 13.83
# User 531:
#   Recommended Streamer: lck_korea, Score: 0.00
# User 247:
#   Recommended Streamer: cdewx, Score: 12.16
# User 4241:
#   Recommended Streamer: rhdgurwns, Score: 11.80
# User 5433:
#   Recommended Streamer: traves, Score: 14.67
# User 7029:
#   Recommended Streamer: brookeab, Score: 12.43
# User 4013:
#   Recommended Streamer: neevi, Score: 18.35
# User 6601:
#   Recommended Streamer: sodapoppin, Score: 12.76
# User 4707:
#   Recommended Streamer: soyfelipez360, Score: 13.78
# User 3575:
#   Recommended Streamer: tfblade, Score: 10.05
# User 1874:
#   Recommended Streamer: sardoche, Score: 19.38
# User 1446:
#   Recommended Streamer: randomrambo, Score: 14.53
# User 2996:
#   Recommended Streamer: zotieboy, Score: 14.26
# User 3975:
#   Recommended Streamer: buddha, Score: 18.19
# User 4970:
#   Recommended Streamer: makatao, Score: 11.84
# User 6561:
#   Recommended Streamer: c_a_k_e, Score: 12.03
# User 5133:
#   Recommended Streamer: drdisrespect, Score: 14.10
# User 4117:
#   Recommended Streamer: arlieshaban, Score: 11.75
# User 4674:
#   Recommended Streamer: buddha, Score: 15.66
#   Recommended Streamer: asmongold, Score: 11.97
# User 4278:
#   Recommended Streamer: summit1g, Score: 12.85
# User 6311:
#   Recommended Streamer: ddahyoni, Score: 10.96
# User 251:
#   Recommended Streamer: kingrichard, Score: 12.81
# User 815:
#   Recommended Streamer: reverse2k, Score: 14.14
# User 1960:
#   Recommended Streamer: dreamhackcsgo_ru, Score: 11.90
# User 6627:
#   Recommended Streamer: tanxlive, Score: 13.55
# User 4999:
#   Recommended Streamer: elajjaz, Score: 3.57
# User 3715:
#   Recommended Streamer: snutzy, Score: 11.87
# User 6686:
#   Recommended Streamer: hashinshin, Score: 14.13
# User 1610:
#   Recommended Streamer: tfblade, Score: 17.23
# User 713:
#   Recommended Streamer: tfue, Score: 14.53
# User 6605:
#   Recommended Streamer: weplayesport_ru, Score: 13.95
# User 4770:
#   Recommended Streamer: gorgc, Score: 13.17
# User 2973:
#   Recommended Streamer: yassuo, Score: 14.58
# User 6193:
#   Recommended Streamer: tekken, Score: 18.20
# User 334:
#   Recommended Streamer: tfue, Score: 13.26
# User 5945:
#   Recommended Streamer: lirik, Score: 18.14
# User 1204:
#   Recommended Streamer: arigameplays, Score: 22.91
# User 6231:
#   Recommended Streamer: sypherpk, Score: 14.76
# User 1678:
#   Recommended Streamer: riotgames, Score: 14.44
# User 1982:
#   Recommended Streamer: the_happy_hob, Score: 11.33
# User 1817:
#   Recommended Streamer: versuta, Score: 13.40
# User 5063:
#   Recommended Streamer: immortoru, Score: 11.26
# User 474:
#   Recommended Streamer: denly, Score: 16.53
# User 4846:
#   Recommended Streamer: gotaga, Score: 15.52
# User 6818:
#   Recommended Streamer: solaryfortnite, Score: 12.45
# User 5867:
#   Recommended Streamer: tidesoftime, Score: 19.16
# User 1548:
#   Recommended Streamer: jinu6734, Score: 18.15
# User 6604:
#   Recommended Streamer: asmongold, Score: 12.89
# User 1128:
#   Recommended Streamer: thijs, Score: 12.96
# User 3625:
#   Recommended Streamer: summit1g, Score: 14.11
# User 2310:
#   Recommended Streamer: ffaka, Score: 20.32
# User 5268:
#   Recommended Streamer: chaseshaco, Score: 13.05
# User 1126:
#   Recommended Streamer: asmongold, Score: 16.93
# User 1852:
#   Recommended Streamer: ogaminglol, Score: 13.64
# User 6753:
#   Recommended Streamer: dota2ruhub, Score: 12.71
# User 6616:
#   Recommended Streamer: masteerxd, Score: 12.27
# User 5846:
#   Recommended Streamer: ukogmonkey, Score: 14.69
# User 6881:
#   Recommended Streamer: relaxing234, Score: 18.05
# User 3103:
#   Recommended Streamer: sizophren, Score: 12.65
# User 2609:
#   Recommended Streamer: emongg, Score: 22.61
# User 2968:
#   Recommended Streamer: nickmercs, Score: 15.64
# User 3210:
#   Recommended Streamer: shroud, Score: 17.67
#   Recommended Streamer: rainbow6, Score: 16.93
# User 3604:
#   Recommended Streamer: mongraal, Score: 14.26
# User 3761:
#   Recommended Streamer: giantwaffle, Score: 12.32
# User 2315:
#   Recommended Streamer: sardoche, Score: 14.16
# User 1707:
#   Recommended Streamer: aydan, Score: 17.33
# User 1251:
#   Recommended Streamer: data_dave, Score: 14.69
# User 90:
#   Recommended Streamer: timthetatman, Score: 16.49
# User 3978:
#   Recommended Streamer: mrnosleep, Score: 17.29
# User 1245:
#   Recommended Streamer: iamcristinini, Score: 11.91
# User 2722:
#   Recommended Streamer: mrsavage, Score: 16.68
# User 468:
#   Recommended Streamer: soyfelipez360, Score: 13.78
# User 3289:
#   Recommended Streamer: juice, Score: 15.01
# User 2244:
#   Recommended Streamer: solaryfortnite, Score: 17.34
# User 677:
#   Recommended Streamer: tvcrank, Score: 22.52
# User 966:
#   Recommended Streamer: esl_csgo, Score: 19.79
# User 4043:
#   Recommended Streamer: symfuhny, Score: 15.64
# User 262:
#   Recommended Streamer: rakin, Score: 8.88
# User 4914:
#   Recommended Streamer: yapyap30, Score: 21.06
# User 120:
#   Recommended Streamer: supertf, Score: 12.35
# User 1046:
#   Recommended Streamer: orangemorange, Score: 12.25
# User 2741:
#   Recommended Streamer: kaparzogo, Score: 14.63
# User 3713:
#   Recommended Streamer: tonton, Score: 15.28
# User 2280:
#   Recommended Streamer: swifty, Score: 11.77
# User 3845:
#   Recommended Streamer: overwatchleague, Score: 22.69
# User 3981:
#   Recommended Streamer: domingo, Score: 14.32
# User 3406:
#   Recommended Streamer: dogdog, Score: 16.20
# User 2152:
#   Recommended Streamer: nairomk, Score: 13.47
# User 6396:
#   Recommended Streamer: couragejd, Score: 15.74
# User 5232:
#   Recommended Streamer: sodapoppin, Score: 15.04
# User 480:
#   Recommended Streamer: asmodaitv, Score: 12.22
# User 688:
#   Recommended Streamer: silerlol, Score: 16.17
# User 1818:
#   Recommended Streamer: blackdotatv, Score: 12.42
# User 2407:
#   Recommended Streamer: loserfruit, Score: 3.28
# User 726:
#   Recommended Streamer: riotgames, Score: 13.83
# User 583:
#   Recommended Streamer: renmen1, Score: 17.93
# User 2953:
#   Recommended Streamer: faker, Score: 10.00
# User 5472:
#   Recommended Streamer: buddha, Score: 25.46
# User 5363:
#   Recommended Streamer: nerdhub, Score: 14.35
# User 2617:
#   Recommended Streamer: flyinguwe87, Score: 11.52
# User 6335:
#   Recommended Streamer: sinemasyonnn, Score: 14.00
# User 5422:
#   Recommended Streamer: poopernoodle, Score: 11.50
# User 4024:
#   Recommended Streamer: jrokezftw, Score: 13.15
# User 6827:
#   Recommended Streamer: sypherpk, Score: 15.59
# User 5733:
#   Recommended Streamer: wtcn, Score: 11.03
# User 5849:
#   Recommended Streamer: venruki, Score: 11.93
# User 2810:
#   Recommended Streamer: nymn, Score: 27.74
# User 6537:
#   Recommended Streamer: nightblue3, Score: 13.98
# User 1995:
#   Recommended Streamer: epicenter_en5, Score: 14.13
# User 740:
#   Recommended Streamer: dakotaz, Score: 18.01
# User 5421:
#   Recommended Streamer: riotgames, Score: 14.44
# User 4100:
#   Recommended Streamer: fran, Score: 14.27
# User 5189:
#   Recommended Streamer: carritoskami, Score: 15.94
# User 396:
#   Recommended Streamer: shroud, Score: 17.35
# User 1737:
#   Recommended Streamer: daxak, Score: 12.00
# User 60:
#   Recommended Streamer: dansgaming, Score: 12.05
# User 6128:
#   Recommended Streamer: valkyrae, Score: 11.96
# User 6662:
#   Recommended Streamer: beyou0728, Score: 12.85
# User 4819:
#   Recommended Streamer: kingrichard, Score: 16.60
# User 1522:
#   Recommended Streamer: scarra, Score: 22.20
# User 830:
#   Recommended Streamer: back2warcraft, Score: 14.31
# User 6412:
#   Recommended Streamer: lirik, Score: 14.04
# User 483:
#   Recommended Streamer: tfue, Score: 11.79
# User 5375:
#   Recommended Streamer: demonzz1, Score: 11.82
# User 948:
#   Recommended Streamer: mirandakerry, Score: 14.31
# User 2543:
#   Recommended Streamer: mclaugh, Score: 14.68
# User 6997:
#   Recommended Streamer: dogswellfish, Score: 14.21
# User 1250:
#   Recommended Streamer: bizzle, Score: 20.89
# User 3112:
#   Recommended Streamer: jovirone, Score: 22.10
# User 1458:
#   Recommended Streamer: koil, Score: 12.24
# User 5150:
#   Recommended Streamer: ninja, Score: 10.14
# User 6301:
#   Recommended Streamer: rdulive, Score: 12.06
# User 6048:
#   Recommended Streamer: rajjpatel, Score: 18.00
# User 2312:
#   Recommended Streamer: thaldrinlol, Score: 10.01
# User 1571:
#   Recommended Streamer: g2perkz, Score: 17.48
# User 2962:
#   Recommended Streamer: ninja, Score: 0.00
# User 6879:
#   Recommended Streamer: xargon0731, Score: 14.53
# User 4199:
#   Recommended Streamer: rdulive, Score: 15.22
# User 803:
#   Recommended Streamer: tsm_daequan, Score: 17.16
# User 4873:
#   Recommended Streamer: gripex90, Score: 13.34
# User 5335:
#   Recommended Streamer: cloakzy, Score: 19.42
# User 4950:
#   Recommended Streamer: exileshow, Score: 18.07
# User 1886:
#   Recommended Streamer: faceittv, Score: 10.00
# User 716:
#   Recommended Streamer: rainbow6, Score: 13.12
# User 6643:
#   Recommended Streamer: methodjosh, Score: 13.35
# User 3067:
#   Recommended Streamer: hanryang1125, Score: 13.24
# User 4118:
#   Recommended Streamer: asmongold, Score: 15.00
# User 1233:
#   Recommended Streamer: sodapoppin, Score: 13.26
# User 4411:
#   Recommended Streamer: papaplatte, Score: 11.89
# User 4809:
#   Recommended Streamer: asmongold, Score: 15.65
# User 2867:
#   Recommended Streamer: zeon, Score: 17.78
# User 5544:
#   Recommended Streamer: toyzttv, Score: 12.61
# User 2519:
#   Recommended Streamer: dakotaz, Score: 14.61
# User 4845:
#   Recommended Streamer: solaryfortnite, Score: 9.21
# User 3293:
#   Recommended Streamer: solaryfortnite, Score: 27.49
# User 6791:
#   Recommended Streamer: swimstrim, Score: 14.27

# %%
# Precision: 추천된 항목 중 실제로 사용자가 선호하는 항목의 비율
# Recall: 사용자가 선호하는 모든 항목 중 추천된 항목의 비율

def calculate_precision_recall(testset, predictions_dict, threshold, k):
    user_actual = defaultdict(set)
    user_predicted = defaultdict(list)

    # 테스트 세트에서 각 사용자별 실제 선호 항목(30분이상시청) 추출
    for uid, iid, true_r in testset:
        if true_r >= threshold:
            user_actual[uid].add(iid)

    # 추천된 항목을 사용자별로 저장
    for uid, user_ratings in predictions_dict.items():
        for iid, est in user_ratings:
            user_predicted[uid].append((iid, est))

    precisions = dict()
    recalls = dict()

    # 각 사용자에 대해 Precision과 Recall을 계산
    for uid in user_actual:
        # 상위 k개의 추천 항목
        user_pred_k = sorted(user_predicted[uid], key=lambda x: x[1], reverse=True)[:k]
        user_pred_k = set([iid for iid, _ in user_pred_k])

        # 실제 선호 항목과 추천 항목의 교집합
        tp = len(user_actual[uid].intersection(user_pred_k))

        # Precision과 Recall 계산
        precisions[uid] = tp / len(user_pred_k) if user_pred_k else 0
        recalls[uid] = tp / len(user_actual[uid]) if user_actual[uid] else 0

    # 전체 사용자에 대한 평균 Precision과 Recall
    avg_precision = sum(prec for prec in precisions.values()) / len(precisions)
    avg_recall = sum(rec for rec in recalls.values()) / len(recalls)

    return avg_precision, avg_recall

# 시청시간 threshold 30분으로 지정

# Setting the threshold 30 minutes and calculating average precision and recall
avg_precision, avg_recall = calculate_precision_recall(testset, final_predictions, threshold=30, k=3)

print(f"Average Precision: {avg_precision}")
print(f"Average Recall: {avg_recall}")
# Out:
# Average Precision: 0.7719454329774607
# Average Recall: 0.9919928825622776
